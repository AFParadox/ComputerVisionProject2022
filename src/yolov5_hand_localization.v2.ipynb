# %% [markdown]
# # Hand localization model training with YOLOv5
# In this notebook we will generate a model for the hand recognition and localization task using YOLOv5 and train it.
# The procedure is divided into steps:
# 1) Manage dependencies and main YOLOv5 files
# 2) Download and extract dataset
# 3) Convert annotation of dataset into YOLOv5 format
# 4) Check on from some random samples that conversion is good
# 5) Last steps
# 6) Train the model

# %% [markdown]
# ### 1) Download YOLO and import necessary dependencies

# %%
import os, shutil
import random
if not os.path.isdir('yolov5'):
    os.system('git clone https://github.com/ultralytics/yolov5')

# install and import yolov5 dependencies
# !pip install -qr yolov5/requirements.txt
import torch, random
import numpy as np
from IPython.display import Image, clear_output

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")

# import dependencies to extract dataset
import requests, tarfile, glob

# import & install dependencies needed to convert dataset label format to yolov5
# !apt-get install libmagic-dev
# !pip install python-magic
import magic, re, scipy.io

# import libs to verify conversion in step 4
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
# Out:
#      |████████████████████████████████| 596 kB 25.9 MB/s
# Setup complete. Using torch 1.12.0+cu113 (Tesla T4)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libmagic-mgc libmagic1
# Suggested packages:
#   file
# The following NEW packages will be installed:
#   libmagic-dev libmagic-mgc libmagic1
# 0 upgraded, 3 newly installed, 0 to remove and 49 not upgraded.
# Need to get 332 kB of archives.
# After this operation, 5,552 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-dev amd64 1:5.32-2ubuntu0.4 [79.7 kB]
# Fetched 332 kB in 1s (246 kB/s)
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 155653 files and directories currently installed.)
# Preparing to unpack .../libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic-dev:amd64.
# Preparing to unpack .../libmagic-dev_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-dev:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up libmagic-dev:amd64 (1:5.32-2ubuntu0.4) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-magic
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Installing collected packages: python-magic
# Successfully installed python-magic-0.4.27

# %% [markdown]
# ### 2) Download and extract dataset
# We will now download(if it has not been already downloaded) the Oxford Hand Dataset which contains some images with hands and some Matlab files which will contain a 4 point bounding box around each hand in each image(a file for each image).<br>
# After that we will extract the dataset(only if it has not been already extracted). All three subsets will be extracted, namely:
# - Training set
# - Validation set
# - Test set

# %%
# check if datasets have been downloaded: download it otherwise

# First we import the oxford dataset
oxford_path = "hand_dataset.tar.gz"
if not(os.path.exists(oxford_path)):
    response = requests.get("https://www.robots.ox.ac.uk/~vgg/data/hands/downloads/hand_dataset.tar.gz")
    open(oxford_path, "wb").write(response.content)

# Then the egohands dataset
egohands_path = 'egohands_data.zip'
if not(os.path.exists(egohands_path)):
  response = requests.get('http://vision.soic.indiana.edu/egohands_files/egohands_data.zip')
  open(egohands_path, 'wb').write(response.content)

# And finally we import the hands_over_face dataset, plus all the labels we previously converted
# !git clone https://github.com/afParadox/dataset_CV.git
# Out:
# Cloning into 'dataset_CV'...
# remote: Enumerating objects: 15851, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 15851 (delta 2), reused 0 (delta 0), pack-reused 15845
# Receiving objects: 100% (15851/15851), 1.23 GiB | 17.70 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# Checking out files: 100% (19921/19921), done.

# %%
# !mkdir dataset dataset/images/ dataset/labels/ dataset/egohands
# !mv hand_dataset.tar.gz dataset/
# !mv egohands_data.zip dataset/egohands
# !tar -xvzf dataset/hand_dataset.tar.gz -C dataset/
# !unzip dataset/egohands/egohands_data.zip -d dataset/egohands
# Out:
# Streaming output truncated to the last 5000 lines.
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_161.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_162.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_17.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_18.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_19.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_2.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_20.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_21.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_22.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_23.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_24.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_25.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_26.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_27.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_28.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_29.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_3.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_30.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_31.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_32.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_33.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_34.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_35.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_36.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_37.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_38.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_39.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_4.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_40.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_41.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_42.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_43.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_44.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_45.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_46.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_47.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_48.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_49.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_5.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_50.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_51.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_52.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_53.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_54.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_55.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_56.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_57.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_58.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_59.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_6.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_60.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_61.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_62.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_63.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_64.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_65.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_66.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_67.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_68.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_69.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_7.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_70.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_71.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_72.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_73.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_74.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_75.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_76.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_77.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_78.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_79.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_8.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_80.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_81.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_82.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_83.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_84.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_85.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_86.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_87.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_88.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_89.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_9.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_90.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_91.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_92.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_93.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_94.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_95.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_96.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_97.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_98.jpg
# hand_dataset/validation_dataset/validation_data/images/Movie_forrest_99.jpg
# Archive:  dataset/egohands/egohands_data.zip
#   inflating: dataset/egohands/DEMO_1.m
#   inflating: dataset/egohands/DEMO_2.m
#   inflating: dataset/egohands/README.txt
#    creating: dataset/egohands/_LABELLED_SAMPLES/
#    creating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0011.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0036.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0099.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0113.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0176.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0183.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0184.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0187.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0189.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0206.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0229.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0241.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0295.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0316.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0324.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0333.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0381.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0384.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0484.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0580.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0611.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0647.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0649.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0752.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0781.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0815.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0831.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0906.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0912.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0941.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0954.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0988.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1009.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1024.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1051.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1087.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1106.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1133.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1164.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1196.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1232.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1262.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1279.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1294.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1317.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1338.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1340.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1344.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1362.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1370.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1377.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1379.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1433.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1444.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1470.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1475.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1523.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1536.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1542.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1577.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1613.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1697.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1758.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1761.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1788.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1804.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1812.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1849.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1887.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1914.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1928.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1930.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1945.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1999.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2006.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2008.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2052.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2093.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2208.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2230.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2235.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2265.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2333.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2334.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2358.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2362.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2363.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2366.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2369.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2426.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2427.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2429.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2443.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2491.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2523.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2527.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2619.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2666.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2693.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2699.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/polygons.mat
#    creating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0060.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0073.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0129.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0134.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0141.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0145.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0174.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0183.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0199.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0209.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0211.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0245.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0247.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0266.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0325.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0380.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0390.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0505.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0549.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0552.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0553.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0611.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0659.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0672.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0682.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0702.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0726.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0763.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0779.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0849.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0853.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0861.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0958.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0994.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1000.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1002.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1021.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1024.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1026.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1036.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1074.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1115.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1135.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1185.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1195.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1232.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1245.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1257.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1284.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1335.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1341.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1376.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1392.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1396.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1403.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1435.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1479.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1514.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1523.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1530.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1604.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1647.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1660.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1674.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1675.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1680.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1720.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1770.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1830.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1832.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1837.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1850.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1880.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1924.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1939.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1962.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1983.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2016.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2018.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2071.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2134.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2163.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2176.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2190.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2194.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2296.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2327.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2365.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2369.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2387.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2412.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2423.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2452.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2533.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2554.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2638.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2650.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2662.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2674.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2693.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/polygons.mat
#    creating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0016.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0037.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0074.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0093.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0146.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0299.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0306.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0324.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0388.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0414.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0438.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0469.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0482.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0504.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0536.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0537.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0559.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0577.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0667.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0672.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0743.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0747.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0805.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0873.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0890.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0896.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0903.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0912.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0923.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0935.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0947.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0963.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1013.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1027.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1043.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1054.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1114.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1160.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1164.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1218.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1220.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1223.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1279.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1300.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1340.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1343.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1352.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1353.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1377.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1379.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1407.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1412.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1435.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1441.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1452.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1486.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1550.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1551.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1552.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1609.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1644.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1688.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1689.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1803.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1815.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1913.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1951.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1991.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1993.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2000.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2027.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2090.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2098.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2108.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2138.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2148.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2154.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2165.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2183.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2186.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2206.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2226.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2243.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2292.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2296.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2299.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2332.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2351.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2391.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2402.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2434.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2464.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2499.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2556.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2568.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2591.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2636.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2658.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2674.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2680.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/polygons.mat
#    creating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0016.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0164.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0180.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0226.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0227.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0241.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0276.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0283.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0331.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0334.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0337.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0360.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0411.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0412.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0419.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0427.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0450.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0557.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0562.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0629.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0632.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0637.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0638.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0685.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0707.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0760.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0768.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0804.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0805.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0823.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0858.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0859.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0880.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0911.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0914.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0937.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0955.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0975.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1010.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1048.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1110.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1190.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1203.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1226.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1239.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1254.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1276.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1298.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1314.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1365.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1373.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1432.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1434.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1456.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1462.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1480.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1520.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1550.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1564.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1585.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1612.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1642.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1661.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1672.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1784.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1806.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1829.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1849.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1892.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1905.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1913.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1924.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1937.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1969.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_1986.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2002.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2011.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2022.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2073.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2132.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2133.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2175.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2207.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2238.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2244.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2272.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2321.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2324.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2327.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2371.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2378.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2434.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2438.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2524.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2571.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2580.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2586.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2589.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2649.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_2658.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/polygons.mat
#    creating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0032.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0085.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0093.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0096.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0124.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0145.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0204.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0262.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0263.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0321.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0342.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0350.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0374.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0383.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0403.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0425.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0437.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0439.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0462.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0504.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0530.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0604.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0657.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0677.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0686.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0688.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0695.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0745.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0747.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0751.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0771.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0840.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0856.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0910.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0919.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0944.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_0949.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1027.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1030.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1059.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1138.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1184.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1203.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1267.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1277.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1310.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1322.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1345.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1366.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1433.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1476.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1477.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1484.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1533.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1535.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1580.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1663.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1707.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1745.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1768.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1769.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1770.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1832.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1835.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1876.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1887.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1906.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_1915.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_B_T/frame_2006.jpg
# ...
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0553.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0574.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0577.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0585.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0656.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0690.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0712.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0722.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0724.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0746.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0755.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0762.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0767.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0786.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0793.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0829.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0830.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0863.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0873.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0902.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_0962.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1015.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1017.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1032.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1035.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1056.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1057.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1077.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1104.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1224.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1246.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1259.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1289.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1340.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1373.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1374.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1394.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1404.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1446.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1489.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1492.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1523.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1527.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1536.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1540.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1556.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1623.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1657.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1688.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1747.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1750.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1767.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1801.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1818.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1828.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1832.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1845.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1854.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1907.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1909.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1958.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1960.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_1973.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2000.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2029.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2072.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2110.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2116.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2183.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2243.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2254.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2259.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2318.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2358.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2385.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2433.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2476.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2481.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2541.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2552.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2553.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2565.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2585.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2601.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2666.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2673.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/polygons.mat
#    creating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0015.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0050.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0082.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0137.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0158.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0173.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0241.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0260.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0273.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0301.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0378.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0389.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0400.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0459.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0478.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0502.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0540.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0542.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0543.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0552.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0580.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0620.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0696.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0716.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0732.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0736.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0766.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0804.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0855.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0876.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0882.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0912.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0961.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0976.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0981.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0987.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1014.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1035.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1072.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1144.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1170.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1172.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1177.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1184.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1187.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1188.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1208.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1243.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1376.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1488.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1495.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1506.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1513.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1535.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1555.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1577.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1593.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1628.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1678.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1694.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1765.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1787.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1805.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1821.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1830.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1846.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1895.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1900.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1976.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1985.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1999.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2021.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2028.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2034.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2042.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2069.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2081.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2088.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2163.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2173.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2187.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2194.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2202.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2208.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2274.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2276.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2335.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2347.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2364.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2376.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2393.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2422.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2447.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2551.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2619.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2629.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2673.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2676.jpg
#   inflating: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2683.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2697.jpg
#  extracting: dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/polygons.mat
#   inflating: dataset/egohands/getBoundingBoxes.m
#   inflating: dataset/egohands/getFramePath.m
#   inflating: dataset/egohands/getMetaBy.m
#   inflating: dataset/egohands/getSegmentationMask.m
#   inflating: dataset/egohands/metadata.mat
#   inflating: dataset/egohands/showLabelsOnFrame.m

# %% [markdown]
# Now we organize the three datasets that we downloaded into a single one, removing all non-necessary files, and renaming the files when necessary, as in the case of the egohands dataset.
# The photos included in the evaluation dataset provided by the professor get removed from the dataset used in these cells.
# In the case of the egohands dataset we also get rid of the whole folders where the photos from the evaluation dataset have been taken. From the total of 48 subfolders in the dataset, only 39 are been used for the training.

# %%
final_path = 'dataset/images/'

# %%
# egohands
path = '/content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/'
counter = 1000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/'
counter = 2000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/'
counter = 4000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/'
counter = 3000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_H_S/'
counter = 5000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_S_H/'
counter = 6000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/CARDS_LIVINGROOM_T_B/'
counter = 7000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/CARDS_OFFICE_S_B/'
counter = 8000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/CARDS_OFFICE_T_H/'
counter = 9000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/CHESS_COURTYARD_H_S/'
counter = 10000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/CHESS_COURTYARD_S_H/'
counter = 11000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/CHESS_COURTYARD_T_B/'
counter = 12000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/CHESS_LIVINGROOM_B_S/'
counter = 13000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/CHESS_LIVINGROOM_H_T/'
counter = 14000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/CHESS_LIVINGROOM_S_B/'
counter = 15000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/CHESS_LIVINGROOM_T_H/'
counter = 16000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/CHESS_OFFICE_H_T/'
counter = 17000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/CHESS_OFFICE_S_B/'
counter = 18000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/CHESS_OFFICE_T_H/'
counter = 19000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/JENGA_COURTYARD_H_B/'
counter = 20000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/JENGA_COURTYARD_S_T/'
counter = 21000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/JENGA_COURTYARD_T_S/'
counter = 22000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/JENGA_LIVINGROOM_B_H/'
counter = 23000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/JENGA_LIVINGROOM_S_T/'
counter = 24000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/JENGA_LIVINGROOM_T_S/'
counter = 25000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/JENGA_OFFICE_B_S/'
counter = 26000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/JENGA_OFFICE_H_T/'
counter = 27000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/JENGA_OFFICE_S_B/'
counter = 28000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/JENGA_OFFICE_T_H/'
counter = 29000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_COURTYARD_H_T/'
counter = 30000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_COURTYARD_S_B/'
counter = 31000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_COURTYARD_T_H/'
counter = 32000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_LIVINGROOM_B_T/'
counter = 33000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_LIVINGROOM_H_S/'
counter = 34000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_LIVINGROOM_S_H/'
counter = 35000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_LIVINGROOM_T_B/'
counter = 36000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_H_B/'
counter = 37000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/'
counter = 38000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

path = '/content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/'
counter = 39000
for file in sorted(glob.glob(path + '*.jpg')):
  new_name = path + str(counter) + '.jpg'
  print(file + ' -> ' + new_name)
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

# !rm -rf dataset/egohands/
# Out:
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0011.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1000.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0036.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1001.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0099.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1002.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0113.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1003.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0176.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1004.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0183.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1005.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0184.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1006.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0187.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1007.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0189.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1008.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0206.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1009.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0229.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1010.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0241.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1011.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0295.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1012.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0316.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1013.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0324.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1014.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0333.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1015.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0381.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1016.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0384.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1017.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0484.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1018.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0580.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1019.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0611.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1020.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0647.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1021.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0649.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1022.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0752.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1023.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0781.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1024.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0815.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1025.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0831.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1026.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0906.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1027.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0912.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1028.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0941.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1029.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0954.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1030.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_0988.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1031.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1009.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1032.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1024.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1033.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1051.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1034.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1087.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1035.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1106.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1036.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1133.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1037.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1164.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1038.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1196.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1039.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1232.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1040.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1262.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1041.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1279.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1042.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1294.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1043.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1317.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1044.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1338.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1045.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1340.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1046.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1344.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1047.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1362.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1048.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1370.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1049.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1377.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1050.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1379.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1051.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1433.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1052.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1444.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1053.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1470.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1054.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1475.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1055.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1523.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1056.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1536.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1057.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1542.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1058.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1577.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1059.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1613.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1060.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1697.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1061.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1758.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1062.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1761.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1063.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1788.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1064.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1804.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1065.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1812.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1066.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1849.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1067.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1887.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1068.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1914.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1069.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1928.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1070.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1930.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1071.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1945.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1072.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_1999.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1073.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2006.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1074.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2008.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1075.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2052.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1076.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2093.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1077.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2208.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1078.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2230.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1079.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2235.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1080.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2265.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1081.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2333.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1082.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2334.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1083.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2358.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1084.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2362.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1085.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2363.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1086.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2366.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1087.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2369.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1088.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2426.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1089.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2427.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1090.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2429.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1091.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2443.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1092.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2491.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1093.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2523.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1094.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2527.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1095.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2619.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1096.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2666.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1097.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2693.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1098.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/frame_2699.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_B_T/1099.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0060.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2000.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0073.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2001.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0129.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2002.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0134.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2003.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0141.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2004.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0145.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2005.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0174.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2006.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0183.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2007.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0199.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2008.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0209.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2009.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0211.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2010.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0245.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2011.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0247.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2012.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0266.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2013.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0325.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2014.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0380.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2015.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0390.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2016.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0505.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2017.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0549.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2018.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0552.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2019.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0553.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2020.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0611.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2021.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0659.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2022.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0672.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2023.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0682.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2024.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0702.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2025.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0726.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2026.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0763.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2027.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0779.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2028.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0849.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2029.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0853.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2030.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0861.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2031.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0958.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2032.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_0994.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2033.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1000.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2034.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1002.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2035.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1021.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2036.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1024.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2037.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1026.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2038.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1036.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2039.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1074.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2040.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1115.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2041.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1135.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2042.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1185.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2043.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1195.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2044.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1232.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2045.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1245.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2046.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1257.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2047.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1284.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2048.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1335.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2049.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1341.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2050.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1376.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2051.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1392.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2052.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1396.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2053.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1403.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2054.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1435.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2055.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1479.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2056.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1514.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2057.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1523.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2058.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1530.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2059.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1604.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2060.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1647.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2061.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1660.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2062.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1674.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2063.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1675.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2064.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1680.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2065.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1720.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2066.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1770.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2067.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1830.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2068.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1832.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2069.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1837.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2070.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1850.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2071.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1880.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2072.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1924.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2073.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1939.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2074.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1962.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2075.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_1983.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2076.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2016.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2077.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2018.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2078.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2071.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2079.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2134.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2080.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2163.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2081.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2176.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2082.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2190.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2083.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2194.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2084.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2296.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2085.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2327.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2086.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2365.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2087.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2369.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2088.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2387.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2089.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2412.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2090.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2423.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2091.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2452.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2092.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2533.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2093.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2554.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2094.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2638.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2095.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2650.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2096.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2662.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2097.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2674.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2098.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/frame_2693.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_H_S/2099.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0016.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4000.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0037.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4001.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0074.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4002.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0093.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4003.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0146.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4004.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0299.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4005.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0306.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4006.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0324.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4007.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0388.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4008.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0414.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4009.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0438.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4010.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0469.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4011.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0482.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4012.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0504.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4013.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0536.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4014.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0537.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4015.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0559.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4016.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0577.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4017.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0667.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4018.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0672.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4019.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0743.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4020.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0747.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4021.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0805.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4022.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0873.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4023.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0890.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4024.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0896.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4025.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0903.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4026.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0912.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4027.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0923.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4028.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0935.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4029.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0947.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4030.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_0963.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4031.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1013.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4032.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1027.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4033.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1043.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4034.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1054.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4035.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1114.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4036.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1160.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4037.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1164.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4038.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1218.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4039.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1220.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4040.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1223.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4041.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1279.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4042.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1300.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4043.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1340.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4044.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1343.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4045.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1352.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4046.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1353.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4047.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1377.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4048.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1379.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4049.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1407.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4050.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1412.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4051.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1435.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4052.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1441.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4053.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1452.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4054.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1486.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4055.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1550.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4056.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1551.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4057.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1552.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4058.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1609.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4059.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1644.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4060.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1688.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4061.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1689.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4062.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1803.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4063.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1815.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4064.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1913.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4065.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1951.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4066.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1991.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4067.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_1993.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4068.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2000.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4069.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2027.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4070.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2090.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4071.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2098.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4072.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2108.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4073.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2138.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4074.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2148.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4075.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2154.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4076.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2165.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4077.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2183.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4078.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2186.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4079.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2206.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4080.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2226.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4081.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2243.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4082.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2292.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4083.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2296.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4084.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2299.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4085.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2332.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4086.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2351.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4087.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2391.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4088.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2402.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4089.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2434.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4090.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2464.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4091.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2499.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4092.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2556.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4093.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2568.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4094.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2591.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4095.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2636.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4096.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2658.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4097.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2674.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4098.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/frame_2680.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_S_H/4099.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0016.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/3000.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0164.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/3001.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0180.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/3002.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0226.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/3003.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0227.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/3004.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0241.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/3005.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0276.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/3006.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0283.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/3007.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/frame_0331.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/CARDS_COURTYARD_T_B/3008.jpg
# ...
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2565.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/38095.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2585.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/38096.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2601.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/38097.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2666.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/38098.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/frame_2673.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_S_T/38099.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0015.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39000.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0050.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39001.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0082.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39002.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0137.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39003.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0158.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39004.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0173.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39005.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0241.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39006.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0260.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39007.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0273.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39008.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0301.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39009.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0378.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39010.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0389.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39011.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0400.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39012.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0459.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39013.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0478.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39014.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0502.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39015.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0540.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39016.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0542.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39017.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0543.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39018.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0552.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39019.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0580.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39020.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0620.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39021.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0696.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39022.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0716.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39023.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0732.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39024.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0736.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39025.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0766.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39026.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0804.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39027.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0855.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39028.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0876.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39029.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0882.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39030.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0912.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39031.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0961.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39032.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0976.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39033.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0981.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39034.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_0987.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39035.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1014.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39036.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1035.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39037.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1072.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39038.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1144.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39039.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1170.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39040.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1172.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39041.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1177.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39042.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1184.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39043.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1187.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39044.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1188.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39045.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1208.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39046.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1243.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39047.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1376.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39048.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1488.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39049.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1495.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39050.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1506.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39051.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1513.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39052.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1535.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39053.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1555.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39054.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1577.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39055.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1593.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39056.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1628.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39057.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1678.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39058.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1694.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39059.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1765.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39060.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1787.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39061.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1805.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39062.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1821.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39063.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1830.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39064.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1846.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39065.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1895.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39066.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1900.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39067.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1976.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39068.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1985.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39069.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_1999.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39070.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2021.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39071.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2028.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39072.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2034.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39073.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2042.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39074.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2069.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39075.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2081.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39076.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2088.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39077.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2163.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39078.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2173.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39079.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2187.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39080.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2194.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39081.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2202.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39082.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2208.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39083.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2274.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39084.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2276.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39085.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2335.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39086.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2347.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39087.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2364.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39088.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2376.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39089.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2393.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39090.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2422.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39091.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2447.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39092.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2551.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39093.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2619.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39094.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2629.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39095.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2673.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39096.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2676.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39097.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2683.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39098.jpg
# /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/frame_2697.jpg -> /content/dataset/egohands/_LABELLED_SAMPLES/PUZZLE_OFFICE_T_S/39099.jpg

# %%
# oxford 
path = '/content/dataset/hand_dataset/training_dataset/training_data/images/'
for file in os.listdir(path):
  if file == '._.DS_Store' or file == '.DS_Store': continue
  os.rename(path + file, final_path + file)

path = '/content/dataset/hand_dataset/validation_dataset/validation_data/images/'
for file in os.listdir(path):
  if file == '._.DS_Store' or file == '.DS_Store': continue
  os.rename(path + file, final_path + file)

path = '/content/dataset/hand_dataset/test_dataset/test_data/images/'
counter = 40000
for file in sorted(glob.glob(path + '*.jpg')):
  if file == '._.DS_Store' or file == '.DS_Store': continue
  os.rename(file, final_path + str(counter) + '.jpg')
  counter += 1

# !rm -rf dataset/hand_dataset 
# !rm dataset/hand_dataset.tar.gz

# %%
# hands over face
path = 'dataset_CV/hands_over_face/'
for file in os.listdir(path):
  os.rename(path + file, final_path + file)

# %%
# Finally we move the labels we imported to the labels folder
final_path = 'dataset/labels/'
initial_path = 'dataset_CV/labels/'
for file in os.listdir(initial_path):
  os.rename(initial_path + file, final_path + file)

# !rm -rf dataset_CV

# %% [markdown]
# Here we check that we have the same number of images and annotation files, and that their names coincide.

# %%
print(len(os.listdir('dataset/images/')))
print(len(os.listdir('dataset/labels/')))

path_1 = 'dataset/images/'
path_2 = 'dataset/labels/'

for file in os.listdir(path_1):
    txt_name = file[:-4] + '.txt'
    if txt_name not in os.listdir(path_2):
        print(txt_name + ' missing')
# Out:
# 9816
# 9816

# %% [markdown]
# Now we want to create the validation and test set.

# %%
# !mkdir dataset/validation/ dataset/validation/images/ dataset/validation/labels/
# !mkdir dataset/test/ dataset/test/images dataset/test/labels

random.seed(10000)

images_path = 'dataset/images/'
labels_path = 'dataset/labels/'
validation_images = 'dataset/validation/images/'
validation_labels = 'dataset/validation/labels/'
test_images = 'dataset/test/images/'
test_labels = 'dataset/test/labels/'

# Here we populate the validation set
for i in range(1000):
  list = sorted(os.listdir(images_path))
  n = random.randint(0, len(list) - 1)
  print(list[n][:-4] + ' -> validation')
  os.rename(images_path + list[n], validation_images + list[n])
  os.rename(labels_path + list[n][:-4] + '.txt', validation_labels + list[n][:-4] + '.txt')

# Here we populate the test set


for i in range(800):
  list = sorted(os.listdir(images_path))
  n = random.randint(0, len(list) - 1)
  print(list[n][:-4] + ' -> test')
  os.rename(images_path + list[n], test_images + list[n])
  os.rename(labels_path + list[n][:-4] + '.txt', test_labels + list[n][:-4] + '.txt')
  
print(len(os.listdir(validation_images)))
print(len(os.listdir(validation_labels)))
print(len(os.listdir(test_images)))
print(len(os.listdir(test_labels)))
# Out:
# VOC2010_686 -> validation
# 8098 -> validation
# 14052 -> validation
# 251 -> validation
# 12089 -> validation
# 10038 -> validation
# 40683 -> validation
# VOC2007_751 -> validation
# Buffy_404 -> validation
# 33061 -> validation
# 23079 -> validation
# VOC2010_58 -> validation
# Movie_4weds_132 -> validation
# 10087 -> validation
# Buffy_12 -> validation
# 12000 -> validation
# VOC2010_65 -> validation
# 40152 -> validation
# 120 -> validation
# Buffy_446 -> validation
# VOC2010_749 -> validation
# VOC2010_739 -> validation
# 40766 -> validation
# VOC2010_1082 -> validation
# VOC2010_1203 -> validation
# 31059 -> validation
# 25069 -> validation
# 21077 -> validation
# Buffy_314 -> validation
# 11051 -> validation
# Movie_forrest_23 -> validation
# 3047 -> validation
# 18035 -> validation
# Inria_75 -> validation
# VOC2007_197 -> validation
# Movie_forrest_103 -> validation
# 4059 -> validation
# Buffy_478 -> validation
# Movie_4weds_151 -> validation
# VOC2010_1236 -> validation
# VOC2007_679 -> validation
# VOC2010_811 -> validation
# Buffy_329 -> validation
# VOC2010_378 -> validation
# 32031 -> validation
# 18056 -> validation
# 8096 -> validation
# VOC2007_637 -> validation
# VOC2010_197 -> validation
# VOC2007_816 -> validation
# VOC2010_855 -> validation
# Poselet_328 -> validation
# 20066 -> validation
# Movie_4weds_69 -> validation
# 39038 -> validation
# VOC2007_307 -> validation
# 2008 -> validation
# 40196 -> validation
# 29025 -> validation
# Skin_72 -> validation
# VOC2010_479 -> validation
# VOC2010_604 -> validation
# 17097 -> validation
# VOC2010_675 -> validation
# Buffy_545 -> validation
# VOC2010_113 -> validation
# 134 -> validation
# VOC2010_788 -> validation
# 13094 -> validation
# VOC2010_1214 -> validation
# 30040 -> validation
# Movie_4weds_80 -> validation
# Poselet_259 -> validation
# VOC2007_382 -> validation
# 31085 -> validation
# Inria_291 -> validation
# Poselet_58 -> validation
# Skin_51 -> validation
# VOC2010_689 -> validation
# 40086 -> validation
# VOC2007_99 -> validation
# Buffy_47 -> validation
# VOC2010_1330 -> validation
# 37055 -> validation
# Inria_380 -> validation
# 40024 -> validation
# 13068 -> validation
# 18052 -> validation
# 40282 -> validation
# 35035 -> validation
# 13016 -> validation
# Movie_4weds_206 -> validation
# 31082 -> validation
# Inria_106 -> validation
# Movie_apollo13_22 -> validation
# 29091 -> validation
# 194 -> validation
# 5085 -> validation
# 38048 -> validation
# Movie_4weds_221 -> validation
# 8090 -> validation
# Movie_4weds_166 -> validation
# Poselet_282 -> validation
# 39010 -> validation
# Movie_4weds_164 -> validation
# 20051 -> validation
# 7054 -> validation
# VOC2010_1068 -> validation
# VOC2010_651 -> validation
# 10066 -> validation
# VOC2010_930 -> validation
# 28028 -> validation
# 9001 -> validation
# Buffy_528 -> validation
# VOC2010_37 -> validation
# VOC2010_598 -> validation
# Inria_464 -> validation
# Movie_boy_106 -> validation
# Skin_287 -> validation
# 21087 -> validation
# VOC2010_419 -> validation
# 19013 -> validation
# 3051 -> validation
# Buffy_223 -> validation
# Inria_303 -> validation
# 40561 -> validation
# Buffy_150 -> validation
# 11004 -> validation
# VOC2007_17 -> validation
# VOC2007_61 -> validation
# 30064 -> validation
# 40006 -> validation
# 25049 -> validation
# VOC2007_297 -> validation
# 22094 -> validation
# 3032 -> validation
# VOC2007_583 -> validation
# 15027 -> validation
# Inria_445 -> validation
# 15016 -> validation
# 31024 -> validation
# Inria_54 -> validation
# 6091 -> validation
# VOC2010_743 -> validation
# 28050 -> validation
# 28026 -> validation
# VOC2007_300 -> validation
# Buffy_123 -> validation
# 9052 -> validation
# VOC2010_437 -> validation
# VOC2010_956 -> validation
# 5023 -> validation
# Poselet_300 -> validation
# 27068 -> validation
# VOC2007_528 -> validation
# 264 -> validation
# Inria_76 -> validation
# Skin_30 -> validation
# 31091 -> validation
# 27084 -> validation
# 36087 -> validation
# Movie_apollo13_103 -> validation
# 17057 -> validation
# 59 -> validation
# 17061 -> validation
# 2025 -> validation
# Buffy_49 -> validation
# 26006 -> validation
# 29095 -> validation
# 20033 -> validation
# 40330 -> validation
# VOC2007_47 -> validation
# 11073 -> validation
# 1045 -> validation
# Poselet_113 -> validation
# VOC2010_759 -> validation
# 40751 -> validation
# VOC2007_342 -> validation
# 19051 -> validation
# VOC2010_1410 -> validation
# 13045 -> validation
# 40505 -> validation
# Skin_111 -> validation
# VOC2010_20 -> validation
# 39046 -> validation
# 40445 -> validation
# 39039 -> validation
# Inria_317 -> validation
# 19016 -> validation
# VOC2010_958 -> validation
# VOC2010_814 -> validation
# VOC2007_13 -> validation
# 40621 -> validation
# 18049 -> validation
# 32002 -> validation
# 2012 -> validation
# Inria_174 -> validation
# VOC2007_9 -> validation
# 1025 -> validation
# 20077 -> validation
# Movie_apollo13_8 -> validation
# Inria_188 -> validation
# 26099 -> validation
# 40076 -> validation
# 6025 -> validation
# VOC2007_286 -> validation
# Movie_apollo13_30 -> validation
# 33096 -> validation
# 2004 -> validation
# 30078 -> validation
# 40080 -> validation
# 25097 -> validation
# Skin_200 -> validation
# 24072 -> validation
# 20095 -> validation
# VOC2010_1435 -> validation
# Movie_forrest_130 -> validation
# 1063 -> validation
# 40108 -> validation
# 35006 -> validation
# 168 -> validation
# 38028 -> validation
# Poselet_274 -> validation
# Buffy_77 -> validation
# 179 -> validation
# 39025 -> validation
# VOC2007_215 -> validation
# VOC2010_1033 -> validation
# VOC2007_445 -> validation
# 4086 -> validation
# 40456 -> validation
# Inria_310 -> validation
# 37018 -> validation
# 40257 -> validation
# 38098 -> validation
# Movie_4weds_190 -> validation
# 19046 -> validation
# VOC2007_240 -> validation
# Inria_44 -> validation
# Buffy_85 -> validation
# VOC2010_1036 -> validation
# 7023 -> validation
# 39049 -> validation
# Skin_294 -> validation
# 10064 -> validation
# Movie_forrest_107 -> validation
# 76 -> validation
# 21091 -> validation
# 40262 -> validation
# Poselet_253 -> validation
# 11060 -> validation
# VOC2010_890 -> validation
# 26007 -> validation
# 1081 -> validation
# Poselet_321 -> validation
# Movie_4weds_186 -> validation
# Movie_4weds_149 -> validation
# 21008 -> validation
# 259 -> validation
# Skin_93 -> validation
# 6052 -> validation
# 40106 -> validation
# Movie_4weds_110 -> validation
# 37081 -> validation
# 5017 -> validation
# 35070 -> validation
# Buffy_435 -> validation
# 5096 -> validation
# 2074 -> validation
# Buffy_65 -> validation
# VOC2010_227 -> validation
# Skin_65 -> validation
# 40276 -> validation
# 32099 -> validation
# 40243 -> validation
# 40690 -> validation
# 25092 -> validation
# Buffy_235 -> validation
# Inria_386 -> validation
# 40018 -> validation
# Poselet_303 -> validation
# Buffy_442 -> validation
# Inria_35 -> validation
# 6072 -> validation
# VOC2010_1373 -> validation
# VOC2010_248 -> validation
# 1049 -> validation
# 15057 -> validation
# Skin_295 -> validation
# VOC2010_764 -> validation
# 3096 -> validation
# 2014 -> validation
# VOC2010_1237 -> validation
# VOC2010_1125 -> validation
# 40404 -> validation
# Buffy_304 -> validation
# VOC2007_30 -> validation
# 38062 -> validation
# Skin_138 -> validation
# Movie_4weds_72 -> validation
# 3011 -> validation
# 32066 -> validation
# 31055 -> validation
# VOC2010_910 -> validation
# VOC2010_898 -> validation
# VOC2010_585 -> validation
# 39047 -> validation
# Movie_apollo13_118 -> validation
# 8023 -> validation
# 40534 -> validation
# 31003 -> validation
# 35013 -> validation
# VOC2010_1320 -> validation
# Buffy_171 -> validation
# 25091 -> validation
# 16071 -> validation
# Inria_307 -> validation
# Inria_193 -> validation
# 10016 -> validation
# Skin_202 -> validation
# 16052 -> validation
# 35017 -> validation
# Movie_4weds_30 -> validation
# 2050 -> validation
# Inria_167 -> validation
# 35078 -> validation
# Inria_203 -> validation
# 11032 -> validation
# Poselet_311 -> validation
# 14043 -> validation
# 22015 -> validation
# Movie_boy_55 -> validation
# 4020 -> validation
# Movie_boy_111 -> validation
# 11080 -> validation
# 40060 -> validation
# 28062 -> validation
# VOC2007_541 -> validation
# 38066 -> validation
# VOC2007_271 -> validation
# VOC2010_748 -> validation
# 40550 -> validation
# 9002 -> validation
# 28 -> validation
# 36041 -> validation
# VOC2007_729 -> validation
# 40796 -> validation
# 40491 -> validation
# VOC2010_34 -> validation
# 29016 -> validation
# Skin_144 -> validation
# VOC2007_813 -> validation
# Inria_22 -> validation
# VOC2010_1127 -> validation
# 7075 -> validation
# 18033 -> validation
# 19047 -> validation
# 38090 -> validation
# 16054 -> validation
# 40344 -> validation
# 7009 -> validation
# Inria_13 -> validation
# Movie_boy_72 -> validation
# VOC2007_662 -> validation
# 153 -> validation
# Movie_4weds_86 -> validation
# 294 -> validation
# Movie_apollo13_37 -> validation
# 7022 -> validation
# Movie_forrest_117 -> validation
# 18069 -> validation
# Skin_291 -> validation
# 40711 -> validation
# 10007 -> validation
# VOC2010_1305 -> validation
# VOC2010_847 -> validation
# 130 -> validation
# 7071 -> validation
# 40809 -> validation
# Poselet_254 -> validation
# 30029 -> validation
# 34062 -> validation
# 9011 -> validation
# Movie_4weds_63 -> validation
# VOC2010_1163 -> validation
# 8035 -> validation
# 40637 -> validation
# Poselet_225 -> validation
# VOC2010_246 -> validation
# Movie_boy_88 -> validation
# 19081 -> validation
# Inria_473 -> validation
# Movie_4weds_84 -> validation
# VOC2010_264 -> validation
# VOC2007_152 -> validation
# 40201 -> validation
# Movie_4weds_107 -> validation
# 36027 -> validation
# 167 -> validation
# Poselet_238 -> validation
# Poselet_381 -> validation
# 18065 -> validation
# 18099 -> validation
# Inria_499 -> validation
# Poselet_108 -> validation
# 40096 -> validation
# Skin_199 -> validation
# 18086 -> validation
# 29092 -> validation
# 23034 -> validation
# 18055 -> validation
# VOC2007_12 -> validation
# VOC2010_332 -> validation
# Poselet_25 -> validation
# Poselet_355 -> validation
# 40471 -> validation
# 34046 -> validation
# Movie_boy_99 -> validation
# VOC2007_443 -> validation
# Inria_198 -> validation
# 24003 -> validation
# VOC2007_549 -> validation
# Inria_540 -> validation
# 40092 -> validation
# 16043 -> validation
# VOC2010_833 -> validation
# Buffy_518 -> validation
# 19010 -> validation
# Inria_344 -> validation
# VOC2010_939 -> validation
# VOC2007_402 -> validation
# Poselet_15 -> validation
# 40029 -> validation
# 48 -> validation
# VOC2010_426 -> validation
# 33016 -> validation
# Inria_255 -> validation
# 24077 -> validation
# Movie_4weds_6 -> validation
# 16000 -> validation
# 34059 -> validation
# 36061 -> validation
# 21057 -> validation
# 36029 -> validation
# VOC2010_147 -> validation
# Buffy_492 -> validation
# Movie_apollo13_151 -> validation
# 14012 -> validation
# Movie_4weds_156 -> validation
# 4094 -> validation
# 1097 -> validation
# Movie_forrest_129 -> validation
# Poselet_64 -> validation
# 14090 -> validation
# 22071 -> validation
# Movie_forrest_42 -> validation
# Inria_218 -> validation
# Poselet_130 -> validation
# 35081 -> validation
# 40264 -> validation
# Buffy_312 -> validation
# 12033 -> validation
# VOC2010_790 -> validation
# VOC2010_1167 -> validation
# 35038 -> validation
# 9030 -> validation
# VOC2010_949 -> validation
# 21011 -> validation
# Poselet_373 -> validation
# 28048 -> validation
# VOC2010_468 -> validation
# Inria_387 -> validation
# VOC2010_417 -> validation
# 34001 -> validation
# 2097 -> validation
# 8024 -> validation
# Movie_boy_81 -> validation
# Movie_4weds_119 -> validation
# Skin_253 -> validation
# 22045 -> validation
# VOC2010_271 -> validation
# 5032 -> validation
# VOC2010_506 -> validation
# VOC2010_223 -> validation
# Skin_162 -> validation
# 28057 -> validation
# VOC2010_1146 -> validation
# 29077 -> validation
# 25046 -> validation
# 301 -> validation
# Buffy_297 -> validation
# 30087 -> validation
# Skin_43 -> validation
# 36034 -> validation
# 243 -> validation
# 2055 -> validation
# Skin_151 -> validation
# Buffy_107 -> validation
# VOC2010_355 -> validation
# VOC2010_363 -> validation
# Inria_379 -> validation
# 27027 -> validation
# Poselet_96 -> validation
# Movie_4weds_68 -> validation
# 36094 -> validation
# VOC2007_544 -> validation
# VOC2010_583 -> validation
# 19072 -> validation
# VOC2010_1156 -> validation
# 122 -> validation
# 13078 -> validation
# 15055 -> validation
# Poselet_387 -> validation
# VOC2010_741 -> validation
# Poselet_159 -> validation
# VOC2007_35 -> validation
# 10068 -> validation
# Buffy_443 -> validation
# Buffy_415 -> validation
# 6099 -> validation
# 40365 -> validation
# 33034 -> validation
# VOC2010_1277 -> validation
# VOC2010_919 -> validation
# VOC2010_135 -> validation
# VOC2007_62 -> validation
# VOC2010_383 -> validation
# 1083 -> validation
# VOC2010_904 -> validation
# 13060 -> validation
# VOC2007_339 -> validation
# VOC2007_162 -> validation
# Buffy_379 -> validation
# 27019 -> validation
# 27080 -> validation
# VOC2010_491 -> validation
# VOC2007_721 -> validation
# VOC2007_284 -> validation
# Skin_109 -> validation
# 21065 -> validation
# 16074 -> validation
# 10001 -> validation
# 269 -> validation
# 9078 -> validation
# Inria_205 -> validation
# 17052 -> validation
# 5036 -> validation
# Movie_apollo13_4 -> validation
# Buffy_407 -> validation
# Poselet_88 -> validation
# 40083 -> validation
# VOC2010_751 -> validation
# 40812 -> validation
# Poselet_193 -> validation
# 26059 -> validation
# 4038 -> validation
# 29049 -> validation
# 27087 -> validation
# 38096 -> validation
# VOC2010_1335 -> validation
# Inria_225 -> validation
# 35010 -> validation
# 31088 -> validation
# 40435 -> validation
# 24047 -> validation
# Inria_461 -> validation
# Buffy_434 -> validation
# 32000 -> validation
# 40624 -> validation
# VOC2010_531 -> validation
# Poselet_230 -> validation
# Movie_boy_82 -> validation
# 26053 -> validation
# Buffy_164 -> validation
# 17046 -> validation
# 11054 -> validation
# VOC2007_739 -> validation
# VOC2010_80 -> validation
# VOC2010_517 -> validation
# Inria_325 -> validation
# VOC2010_400 -> validation
# 40151 -> validation
# 9058 -> validation
# VOC2010_1248 -> validation
# Buffy_342 -> validation
# 34087 -> validation
# 6049 -> validation
# Poselet_13 -> validation
# Inria_321 -> validation
# VOC2007_368 -> validation
# 15080 -> validation
# 34039 -> validation
# Movie_forrest_95 -> validation
# 9071 -> validation
# Poselet_196 -> validation
# VOC2010_326 -> validation
# Skin_289 -> validation
# 40769 -> validation
# 9075 -> validation
# VOC2007_165 -> validation
# 33074 -> validation
# 29062 -> validation
# 23021 -> validation
# 40120 -> validation
# Poselet_249 -> validation
# Inria_412 -> validation
# 21032 -> validation
# 32077 -> validation
# Skin_209 -> validation
# 15085 -> validation
# VOC2010_515 -> validation
# Inria_273 -> validation
# 39066 -> validation
# 24091 -> validation
# 39037 -> validation
# VOC2010_1269 -> validation
# VOC2010_880 -> validation
# 16018 -> validation
# Buffy_84 -> validation
# Buffy_190 -> validation
# VOC2007_757 -> validation
# 30032 -> validation
# Movie_4weds_264 -> validation
# 139 -> validation
# 10023 -> validation
# VOC2007_551 -> validation
# VOC2010_435 -> validation
# 15012 -> validation
# 39012 -> validation
# VOC2010_1118 -> validation
# Movie_forrest_66 -> validation
# 6030 -> validation
# 11066 -> validation
# VOC2007_717 -> validation
# 32009 -> validation
# Movie_apollo13_56 -> validation
# Movie_apollo13_154 -> validation
# 18083 -> validation
# 31071 -> validation
# VOC2010_1143 -> validation
# VOC2007_78 -> validation
# 32020 -> validation
# Movie_forrest_51 -> validation
# Poselet_261 -> validation
# Skin_23 -> validation
# 2016 -> validation
# 40693 -> validation
# 4065 -> validation
# VOC2007_711 -> validation
# 40112 -> validation
# Poselet_129 -> validation
# Poselet_195 -> validation
# VOC2010_1342 -> validation
# VOC2010_1126 -> validation
# 10036 -> validation
# Movie_4weds_13 -> validation
# VOC2010_1359 -> validation
# Skin_198 -> validation
# 16097 -> validation
# Poselet_84 -> validation
# VOC2010_1103 -> validation
# 31098 -> validation
# VOC2010_362 -> validation
# 28034 -> validation
# Skin_90 -> validation
# 28070 -> validation
# 32051 -> validation
# 24081 -> validation
# 21083 -> validation
# 39055 -> validation
# 13013 -> validation
# Skin_79 -> validation
# Skin_268 -> validation
# Skin_96 -> validation
# 25073 -> validation
# 7048 -> validation
# Skin_204 -> validation
# VOC2010_1422 -> validation
# Buffy_332 -> validation
# 32026 -> validation
# VOC2010_634 -> validation
# Inria_73 -> validation
# VOC2007_621 -> validation
# VOC2007_384 -> validation
# VOC2007_516 -> validation
# VOC2010_619 -> validation
# Skin_154 -> validation
# 33 -> validation
# 30042 -> validation
# 13037 -> validation
# VOC2007_64 -> validation
# VOC2010_174 -> validation
# Buffy_64 -> validation
# 7091 -> validation
# Buffy_386 -> validation
# 14013 -> validation
# 10015 -> validation
# Skin_218 -> validation
# Poselet_197 -> validation
# 38058 -> validation
# VOC2010_1123 -> validation
# Poselet_316 -> validation
# Movie_forrest_146 -> validation
# VOC2010_1345 -> validation
# Inria_124 -> validation
# 31 -> validation
# 2040 -> validation
# Movie_forrest_38 -> validation
# VOC2007_146 -> validation
# VOC2010_93 -> validation
# 32012 -> validation
# 6010 -> validation
# VOC2007_84 -> validation
# 39017 -> validation
# 11016 -> validation
# Movie_apollo13_159 -> validation
# 40209 -> validation
# 21037 -> validation
# 29050 -> validation
# Buffy_191 -> validation
# 17026 -> validation
# VOC2010_1189 -> validation
# VOC2010_1336 -> validation
# 25088 -> validation
# VOC2010_81 -> validation
# 24000 -> validation
# 40818 -> validation
# Inria_108 -> validation
# 40078 -> validation
# Buffy_119 -> validation
# VOC2007_168 -> validation
# 40390 -> validation
# VOC2010_994 -> validation
# 37084 -> validation
# Poselet_292 -> validation
# Movie_forrest_83 -> validation
# 40217 -> validation
# VOC2007_476 -> validation
# VOC2010_1360 -> validation
# 199 -> validation
# Poselet_157 -> validation
# VOC2007_795 -> validation
# 8048 -> validation
# 13021 -> validation
# VOC2010_164 -> validation
# 9073 -> validation
# 21064 -> validation
# 28044 -> validation
# Movie_boy_76 -> validation
# VOC2010_882 -> validation
# 40377 -> validation
# VOC2007_272 -> validation
# 25009 -> validation
# Poselet_148 -> validation
# VOC2010_477 -> validation
# 34042 -> validation
# VOC2007_234 -> validation
# Skin_118 -> validation
# 9095 -> validation
# VOC2010_13 -> validation
# 26027 -> validation
# 11098 -> validation
# Movie_4weds_29 -> validation
# 275 -> validation
# VOC2010_421 -> validation
# 20088 -> validation
# VOC2010_1231 -> validation
# 40580 -> validation
# Inria_408 -> validation
# VOC2007_514 -> validation
# 2029 -> validation
# Poselet_280 -> validation
# VOC2007_330 -> validation
# VOC2010_813 -> validation
# 34058 -> validation
# 38070 -> validation
# 35073 -> validation
# VOC2010_87 -> validation
# 22041 -> validation
# VOC2010_793 -> validation
# Buffy_356 -> validation
# VOC2007_710 -> validation
# VOC2010_543 -> validation
# Movie_apollo13_27 -> validation
# Poselet_356 -> validation
# VOC2007_153 -> validation
# 20082 -> validation
# 8072 -> validation
# 25023 -> validation
# 31072 -> validation
# 32054 -> validation
# 181 -> validation
# Poselet_288 -> validation
# 29037 -> validation
# Poselet_132 -> validation
# 22009 -> validation
# Buffy_542 -> validation
# VOC2007_642 -> validation
# 32035 -> validation
# Poselet_198 -> validation
# 29043 -> validation
# VOC2010_859 -> validation
# 17069 -> validation
# 28082 -> validation
# Buffy_229 -> validation
# 20014 -> validation
# 12077 -> validation
# VOC2010_891 -> validation
# VOC2007_114 -> validation
# 40204 -> validation
# 10097 -> validation
# 39065 -> validation
# Inria_265 -> validation
# 40140 -> validation
# 40094 -> validation
# 7052 -> validation
# Inria_355 -> validation
# Skin_129 -> validation
# VOC2007_688 -> validation
# 7094 -> validation
# Buffy_440 -> validation
# Skin_77 -> validation
# VOC2010_915 -> validation
# VOC2010_723 -> validation
# 35056 -> validation
# VOC2007_602 -> validation
# 102 -> validation
# VOC2010_18 -> validation
# VOC2010_626 -> validation
# Buffy_256 -> validation
# 40247 -> validation
# VOC2010_1259 -> validation
# VOC2007_154 -> validation
# VOC2010_541 -> validation
# VOC2010_1322 -> validation
# 2049 -> validation
# VOC2007_798 -> validation
# Inria_252 -> validation
# 40184 -> validation
# 246 -> validation
# Inria_478 -> validation
# 2058 -> validation
# Movie_forrest_101 -> validation
# 8013 -> validation
# 1047 -> validation
# 22048 -> validation
# Poselet_147 -> validation
# 21009 -> validation
# 17014 -> validation
# Movie_forrest_113 -> validation
# 15044 -> validation
# 10052 -> validation
# Inria_313 -> validation
# VOC2010_494 -> validation
# 109 -> validation
# VOC2007_509 -> validation
# 40656 -> validation
# VOC2007_531 -> validation
# Inria_280 -> validation
# Buffy_491 -> validation
# 32017 -> validation
# 40500 -> validation
# 22037 -> validation
# 35079 -> validation
# 10069 -> validation
# VOC2007_29 -> validation
# 18079 -> validation
# 36062 -> validation
# 26054 -> validation
# VOC2010_238 -> validation
# 20055 -> validation
# 14004 -> validation
# 249 -> validation
# Buffy_26 -> validation
# 6036 -> validation
# VOC2010_345 -> validation
# Movie_4weds_26 -> validation
# 14039 -> validation
# 30080 -> validation
# Inria_365 -> validation
# 20000 -> validation
# 37025 -> validation
# 21045 -> validation
# Inria_463 -> validation
# Buffy_126 -> validation
# 34084 -> validation
# Buffy_465 -> validation
# Buffy_230 -> validation
# 37049 -> validation
# VOC2010_976 -> validation
# 4002 -> validation
# 86 -> validation
# 6033 -> validation
# 34023 -> validation
# 21097 -> validation
# 27071 -> validation
# Inria_83 -> validation
# Inria_224 -> validation
# 16040 -> validation
# Movie_4weds_183 -> validation
# 186 -> validation
# Movie_apollo13_78 -> validation
# 1044 -> validation
# 23049 -> validation
# VOC2010_1093 -> validation
# VOC2010_391 -> validation
# 40036 -> validation
# 117 -> validation
# 29056 -> validation
# 28039 -> validation
# Movie_forrest_14 -> validation
# VOC2010_664 -> validation
# VOC2007_54 -> validation
# 40065 -> validation
# 19066 -> validation
# VOC2010_988 -> validation
# Movie_boy_95 -> validation
# Movie_4weds_127 -> validation
# Poselet_326 -> validation
# Inria_419 -> validation
# 40646 -> validation
# Inria_78 -> validation
# 237 -> validation
# 115 -> validation
# VOC2010_1029 -> validation
# VOC2007_235 -> validation
# VOC2010_1445 -> validation
# 9043 -> validation
# 23082 -> validation
# 6047 -> validation
# Movie_4weds_18 -> validation
# VOC2010_810 -> validation
# 9010 -> validation
# 40474 -> validation
# Inria_145 -> validation
# Movie_4weds_250 -> validation
# Inria_323 -> validation
# 40342 -> validation
# Buffy_61 -> validation
# 20002 -> validation
# 10032 -> validation
# 3052 -> validation
# VOC2010_52 -> validation
# 20092 -> validation
# VOC2010_518 -> validation
# Inria_93 -> validation
# 20001 -> validation
# Buffy_481 -> validation
# Movie_apollo13_52 -> validation
# Buffy_38 -> validation
# 20041 -> validation
# Inria_241 -> validation
# 38024 -> validation
# 27042 -> validation
# VOC2010_805 -> validation
# 30001 -> validation
# 8059 -> validation
# 21017 -> validation
# 15056 -> validation
# 12002 -> validation
# 40813 -> validation
# Buffy_11 -> validation
# Movie_4weds_177 -> validation
# 10091 -> validation
# VOC2010_219 -> validation
# VOC2010_921 -> validation
# VOC2010_153 -> validation
# Buffy_278 -> validation
# VOC2010_528 -> validation
# 2078 -> validation
# VOC2010_576 -> validation
# VOC2010_1021 -> validation
# 5047 -> validation
# 15028 -> validation
# 39058 -> validation
# Inria_120 -> validation
# 19002 -> validation
# VOC2007_173 -> validation
# VOC2007_57 -> validation
# 37078 -> validation
# 5015 -> validation
# Skin_19 -> validation
# 39016 -> validation
# Skin_267 -> validation
# Inria_526 -> validation
# Buffy_91 -> validation
# 40800 -> validation
# 35025 -> validation
# VOC2010_132 -> validation
# Movie_apollo13_12 -> validation
# VOC2007_401 -> validation
# 22051 -> validation
# Buffy_303 -> validation
# 34018 -> validation
# 40789 -> validation
# VOC2007_107 -> validation
# VOC2010_1404 -> validation
# VOC2007_191 -> validation
# Movie_apollo13_47 -> validation
# 7017 -> validation
# 36007 -> test
# 189 -> test
# Movie_boy_75 -> test
# Movie_boy_115 -> test
# 20027 -> test
# VOC2007_333 -> test
# VOC2010_865 -> test
# 32081 -> test
# 24008 -> test
# 45 -> test
# VOC2010_1366 -> test
# 8038 -> test
# Skin_255 -> test
# 33028 -> test
# VOC2007_744 -> test
# 34083 -> test
# 20083 -> test
# Buffy_482 -> test
# 32056 -> test
# 33078 -> test
# Buffy_515 -> test
# Movie_forrest_64 -> test
# 22089 -> test
# 37051 -> test
# VOC2010_53 -> test
# 10044 -> test
# 5073 -> test
# 40353 -> test
# 39042 -> test
# Movie_forrest_88 -> test
# Movie_apollo13_131 -> test
# 40651 -> test
# 36092 -> test
# 33037 -> test
# 14092 -> test
# 36073 -> test
# VOC2010_76 -> test
# Skin_257 -> test
# VOC2007_800 -> test
# 7020 -> test
# 10065 -> test
# 15058 -> test
# Movie_apollo13_168 -> test
# VOC2010_292 -> test
# Buffy_468 -> test
# 40158 -> test
# Skin_37 -> test
# Skin_60 -> test
# VOC2010_361 -> test
# Buffy_548 -> test
# 7082 -> test
# 1015 -> test
# 9026 -> test
# Buffy_200 -> test
# Buffy_124 -> test
# 5027 -> test
# 40568 -> test
# 40521 -> test
# 40684 -> test
# VOC2007_665 -> test
# 40644 -> test
# Buffy_325 -> test
# VOC2010_980 -> test
# VOC2010_589 -> test
# 13031 -> test
# 1021 -> test
# VOC2010_1266 -> test
# 22055 -> test
# 19077 -> test
# VOC2010_1055 -> test
# Buffy_199 -> test
# VOC2010_353 -> test
# 40518 -> test
# Poselet_44 -> test
# Movie_apollo13_162 -> test
# 35075 -> test
# 14055 -> test
# 22018 -> test
# 13020 -> test
# Inria_334 -> test
# 36025 -> test
# VOC2010_1089 -> test
# 9093 -> test
# 40709 -> test
# 16072 -> test
# 38031 -> test
# VOC2007_181 -> test
# VOC2010_1369 -> test
# 28007 -> test
# 13000 -> test
# Movie_forrest_106 -> test
# Buffy_520 -> test
# 40156 -> test
# 13053 -> test
# VOC2010_85 -> test
# VOC2007_707 -> test
# VOC2007_308 -> test
# 25047 -> test
# VOC2010_97 -> test
# Buffy_452 -> test
# Movie_4weds_292 -> test
# 6035 -> test
# 40104 -> test
# 40588 -> test
# 23055 -> test
# VOC2010_562 -> test
# 15004 -> test
# 3008 -> test
# 6022 -> test
# VOC2010_913 -> test
# VOC2010_349 -> test
# VOC2007_518 -> test
# 23004 -> test
# Buffy_92 -> test
# 37028 -> test
# 140 -> test
# Inria_91 -> test
# VOC2010_609 -> test
# Buffy_310 -> test
# VOC2007_651 -> test
# 18024 -> test
# VOC2007_515 -> test
# VOC2007_524 -> test
# Poselet_200 -> test
# VOC2010_1147 -> test
# 16084 -> test
# VOC2010_48 -> test
# 6068 -> test
# 8088 -> test
# VOC2010_146 -> test
# 26075 -> test
# 14036 -> test
# VOC2010_1037 -> test
# 18047 -> test
# VOC2007_441 -> test
# 10081 -> test
# 40414 -> test
# VOC2007_128 -> test
# 40675 -> test
# VOC2010_2 -> test
# Poselet_236 -> test
# Inria_328 -> test
# 35076 -> test
# 10010 -> test
# 20099 -> test
# Movie_4weds_83 -> test
# Inria_40 -> test
# VOC2010_887 -> test
# 17080 -> test
# Movie_forrest_156 -> test
# 103 -> test
# 165 -> test
# 34009 -> test
# Movie_apollo13_17 -> test
# Inria_301 -> test
# Movie_apollo13_157 -> test
# VOC2010_1078 -> test
# VOC2010_595 -> test
# Movie_apollo13_102 -> test
# 5063 -> test
# Buffy_88 -> test
# 39083 -> test
# VOC2010_1141 -> test
# 18010 -> test
# Buffy_157 -> test
# 7031 -> test
# VOC2010_931 -> test
# 23060 -> test
# 27013 -> test
# VOC2010_926 -> test
# 17073 -> test
# VOC2007_436 -> test
# 17077 -> test
# 17086 -> test
# VOC2010_256 -> test
# 22087 -> test
# 27016 -> test
# 40010 -> test
# Buffy_35 -> test
# 5090 -> test
# Poselet_178 -> test
# 9074 -> test
# 9014 -> test
# 19054 -> test
# VOC2010_835 -> test
# 8056 -> test
# VOC2010_581 -> test
# 32018 -> test
# 40701 -> test
# Skin_203 -> test
# 11042 -> test
# 10083 -> test
# 26063 -> test
# Poselet_299 -> test
# Buffy_537 -> test
# Movie_4weds_95 -> test
# 34030 -> test
# VOC2010_1339 -> test
# 36011 -> test
# 40364 -> test
# 16042 -> test
# Poselet_162 -> test
# Buffy_156 -> test
# VOC2007_650 -> test
# Inria_43 -> test
# VOC2007_705 -> test
# Buffy_475 -> test
# 15018 -> test
# 11072 -> test
# VOC2010_1396 -> test
# VOC2010_792 -> test
# 40717 -> test
# 30026 -> test
# Buffy_141 -> test
# 4026 -> test
# VOC2007_697 -> test
# VOC2010_610 -> test
# VOC2007_820 -> test
# 17025 -> test
# VOC2010_1204 -> test
# Poselet_153 -> test
# 6074 -> test
# 34071 -> test
# 29098 -> test
# 12038 -> test
# 17085 -> test
# 14098 -> test
# 40226 -> test
# 8084 -> test
# 5044 -> test
# 40327 -> test
# VOC2010_236 -> test
# Skin_173 -> test
# Skin_92 -> test
# 1028 -> test
# 27053 -> test
# 12028 -> test
# 38064 -> test
# 39011 -> test
# 36047 -> test
# 37056 -> test
# 4071 -> test
# Movie_4weds_142 -> test
# VOC2010_614 -> test
# 40592 -> test
# Buffy_317 -> test
# 40793 -> test
# 20029 -> test
# 34078 -> test
# VOC2010_1119 -> test
# 39072 -> test
# VOC2010_134 -> test
# 18096 -> test
# VOC2007_352 -> test
# 15048 -> test
# VOC2010_61 -> test
# VOC2010_951 -> test
# VOC2007_819 -> test
# Movie_4weds_256 -> test
# 20023 -> test
# VOC2007_142 -> test
# VOC2010_228 -> test
# 12026 -> test
# Movie_forrest_149 -> test
# 29070 -> test
# 8049 -> test
# 10034 -> test
# 29036 -> test
# 25037 -> test
# VOC2010_530 -> test
# Movie_forrest_145 -> test
# VOC2007_177 -> test
# Buffy_340 -> test
# 7018 -> test
# Inria_138 -> test
# 1086 -> test
# 17020 -> test
# Inria_260 -> test
# Skin_259 -> test
# 16047 -> test
# VOC2007_553 -> test
# VOC2010_263 -> test
# 17084 -> test
# VOC2010_406 -> test
# Poselet_57 -> test
# 25074 -> test
# 38094 -> test
# Buffy_98 -> test
# 24058 -> test
# Poselet_343 -> test
# 11057 -> test
# 34010 -> test
# VOC2007_77 -> test
# 28003 -> test
# 25077 -> test
# VOC2007_653 -> test
# VOC2007_24 -> test
# Inria_127 -> test
# 1062 -> test
# 40542 -> test
# Movie_boy_71 -> test
# 5082 -> test
# 3081 -> test
# VOC2010_668 -> test
# 2033 -> test
# 32092 -> test
# Inria_220 -> test
# 23017 -> test
# 39048 -> test
# 39003 -> test
# VOC2010_502 -> test
# 31036 -> test
# 34008 -> test
# Movie_4weds_235 -> test
# VOC2010_206 -> test
# Inria_523 -> test
# 13003 -> test
# 18005 -> test
# VOC2010_369 -> test
# Poselet_205 -> test
# Movie_4weds_117 -> test
# Inria_90 -> test
# Movie_4weds_104 -> test
# Poselet_89 -> test
# 20052 -> test
# 289 -> test
# VOC2007_270 -> test
# VOC2010_540 -> test
# 31053 -> test
# VOC2010_467 -> test
# Poselet_144 -> test
# Movie_forrest_59 -> test
# VOC2010_1133 -> test
# VOC2010_207 -> test
# 21023 -> test
# VOC2010_1077 -> test
# Inria_415 -> test
# VOC2010_1124 -> test
# VOC2010_414 -> test
# Inria_400 -> test
# Inria_458 -> test
# 20096 -> test
# VOC2007_305 -> test
# 40586 -> test
# 19096 -> test
# 3054 -> test
# Inria_511 -> test
# Buffy_305 -> test
# 40212 -> test
# VOC2010_1442 -> test
# 40469 -> test
# 30041 -> test
# 35087 -> test
# 5075 -> test
# VOC2010_216 -> test
# VOC2010_1051 -> test
# 279 -> test
# VOC2010_672 -> test
# VOC2007_347 -> test
# 101 -> test
# VOC2007_319 -> test
# VOC2007_167 -> test
# Inria_444 -> test
# 14046 -> test
# 19094 -> test
# 36005 -> test
# 35061 -> test
# Buffy_120 -> test
# 23016 -> test
# 13007 -> test
# 28054 -> test
# VOC2010_869 -> test
# VOC2010_230 -> test
# VOC2010_325 -> test
# Movie_forrest_139 -> test
# 11017 -> test
# 26067 -> test
# 29057 -> test
# 15089 -> test
# VOC2010_441 -> test
# 27037 -> test
# 40439 -> test
# 1053 -> test
# 6086 -> test
# 20076 -> test
# 17054 -> test
# 19083 -> test
# 297 -> test
# VOC2010_33 -> test
# 40172 -> test
# 293 -> test
# 40164 -> test
# 8028 -> test
# 8071 -> test
# 32098 -> test
# VOC2010_1377 -> test
# 27075 -> test
# 6060 -> test
# Inria_316 -> test
# 9054 -> test
# 40022 -> test
# Inria_116 -> test
# 5041 -> test
# 32042 -> test
# 38004 -> test
# Inria_179 -> test
# Buffy_214 -> test
# 39007 -> test
# 4018 -> test
# 40107 -> test
# 40764 -> test
# 36012 -> test
# VOC2010_786 -> test
# 37020 -> test
# Inria_117 -> test
# VOC2010_778 -> test
# 29079 -> test
# Inria_142 -> test
# 9020 -> test
# VOC2007_293 -> test
# 9027 -> test
# 19004 -> test
# VOC2007_93 -> test
# 5051 -> test
# Inria_435 -> test
# 16079 -> test
# 40816 -> test
# Buffy_365 -> test
# VOC2010_394 -> test
# VOC2010_73 -> test
# 29054 -> test
# Inria_149 -> test
# 10027 -> test
# Movie_forrest_120 -> test
# 40799 -> test
# 4068 -> test
# VOC2010_1251 -> test
# VOC2010_1253 -> test
# 16082 -> test
# Inria_372 -> test
# Buffy_438 -> test
# 8064 -> test
# Skin_84 -> test
# 31033 -> test
# 10031 -> test
# 32085 -> test
# 38072 -> test
# 38053 -> test
# 23005 -> test
# VOC2007_506 -> test
# 132 -> test
# Inria_413 -> test
# VOC2010_603 -> test
# VOC2010_106 -> test
# Poselet_301 -> test
# Movie_4weds_70 -> test
# Inria_340 -> test
# VOC2010_17 -> test
# 40292 -> test
# 10047 -> test
# 29081 -> test
# VOC2007_539 -> test
# 34055 -> test
# Skin_172 -> test
# 1050 -> test
# 31063 -> test
# 39071 -> test
# VOC2007_239 -> test
# 18021 -> test
# VOC2010_600 -> test
# 40195 -> test
# VOC2010_1165 -> test
# 11045 -> test
# 3043 -> test
# VOC2007_41 -> test
# 10048 -> test
# 195 -> test
# Poselet_218 -> test
# Inria_395 -> test
# 25096 -> test
# 248 -> test
# Poselet_305 -> test
# VOC2010_998 -> test
# 2053 -> test
# 37023 -> test
# 6067 -> test
# VOC2007_71 -> test
# 40039 -> test
# 40449 -> test
# 12003 -> test
# 7021 -> test
# Inria_403 -> test
# VOC2010_340 -> test
# 33044 -> test
# 25044 -> test
# 14045 -> test
# VOC2007_796 -> test
# 28078 -> test
# Inria_282 -> test
# VOC2007_605 -> test
# VOC2010_1362 -> test
# 6004 -> test
# Movie_forrest_37 -> test
# 260 -> test
# Buffy_360 -> test
# VOC2007_557 -> test
# 40314 -> test
# VOC2010_768 -> test
# VOC2007_719 -> test
# 4099 -> test
# 33035 -> test
# 35031 -> test
# 32050 -> test
# 20093 -> test
# 22080 -> test
# Buffy_253 -> test
# Poselet_219 -> test
# Buffy_338 -> test
# Skin_137 -> test
# 24034 -> test
# VOC2010_1300 -> test
# 37052 -> test
# VOC2007_101 -> test
# 27085 -> test
# 23084 -> test
# 31038 -> test
# Buffy_112 -> test
# VOC2007_624 -> test
# 40736 -> test
# Skin_135 -> test
# 1098 -> test
# 22050 -> test
# Poselet_140 -> test
# 34054 -> test
# 27067 -> test
# VOC2010_1060 -> test
# VOC2010_1218 -> test
# VOC2007_325 -> test
# Movie_4weds_168 -> test
# 40285 -> test
# VOC2007_171 -> test
# 40606 -> test
# 22081 -> test
# VOC2007_260 -> test
# 35065 -> test
# VOC2007_188 -> test
# 38059 -> test
# 16093 -> test
# 15065 -> test
# VOC2010_1024 -> test
# VOC2010_1408 -> test
# Movie_boy_5 -> test
# 40137 -> test
# VOC2007_431 -> test
# Movie_apollo13_112 -> test
# 40354 -> test
# 1040 -> test
# 40692 -> test
# VOC2010_779 -> test
# 13090 -> test
# 37017 -> test
# Movie_4weds_280 -> test
# VOC2010_1291 -> test
# VOC2010_608 -> test
# 21071 -> test
# 6023 -> test
# 11000 -> test
# 26032 -> test
# VOC2007_73 -> test
# 40623 -> test
# 36081 -> test
# VOC2010_96 -> test
# Inria_520 -> test
# 39035 -> test
# 25017 -> test
# Inria_326 -> test
# 40040 -> test
# Movie_forrest_61 -> test
# 40760 -> test
# 10000 -> test
# 14 -> test
# Movie_forrest_93 -> test
# 40223 -> test
# VOC2007_522 -> test
# 4083 -> test
# 27095 -> test
# VOC2010_776 -> test
# 30095 -> test
# VOC2010_828 -> test
# 6007 -> test
# 22082 -> test
# VOC2010_555 -> test
# 16033 -> test
# VOC2010_487 -> test
# 29042 -> test
# Movie_boy_32 -> test
# Inria_170 -> test
# VOC2007_328 -> test
# 8018 -> test
# Buffy_94 -> test
# 11069 -> test
# VOC2010_763 -> test
# VOC2010_217 -> test
# VOC2010_849 -> test
# 7076 -> test
# Movie_apollo13_89 -> test
# 40441 -> test
# Skin_1 -> test
# 27036 -> test
# Poselet_100 -> test
# Poselet_49 -> test
# Inria_70 -> test
# 40149 -> test
# VOC2007_608 -> test
# Skin_115 -> test
# Movie_forrest_112 -> test
# VOC2010_1152 -> test
# VOC2010_276 -> test
# Buffy_106 -> test
# Movie_apollo13_90 -> test
# Buffy_546 -> test
# VOC2007_611 -> test
# Buffy_111 -> test
# VOC2007_23 -> test
# 14024 -> test
# Skin_292 -> test
# 40105 -> test
# 40794 -> test
# 24013 -> test
# 11062 -> test
# 40467 -> test
# VOC2007_604 -> test
# Inria_390 -> test
# Inria_476 -> test
# 229 -> test
# 30074 -> test
# VOC2010_802 -> test
# Movie_apollo13_10 -> test
# Buffy_53 -> test
# VOC2007_529 -> test
# Buffy_167 -> test
# Poselet_52 -> test
# Skin_58 -> test
# 15092 -> test
# VOC2010_789 -> test
# Inria_389 -> test
# 2009 -> test
# 26042 -> test
# Buffy_21 -> test
# 26060 -> test
# 28040 -> test
# Movie_boy_9 -> test
# Buffy_133 -> test
# VOC2010_463 -> test
# Movie_forrest_15 -> test
# 29073 -> test
# 32058 -> test
# 15033 -> test
# 83 -> test
# VOC2010_1107 -> test
# Movie_4weds_215 -> test
# 11087 -> test
# VOC2010_960 -> test
# VOC2010_321 -> test
# VOC2010_255 -> test
# 28006 -> test
# Buffy_319 -> test
# VOC2010_556 -> test
# 27052 -> test
# 33077 -> test
# 40511 -> test
# VOC2010_928 -> test
# 15050 -> test
# Poselet_80 -> test
# Movie_boy_79 -> test
# 17029 -> test
# Poselet_166 -> test
# 40280 -> test
# VOC2010_1321 -> test
# 22054 -> test
# 30048 -> test
# Movie_forrest_122 -> test
# VOC2010_265 -> test
# VOC2010_291 -> test
# 30046 -> test
# Skin_296 -> test
# 17051 -> test
# Movie_forrest_58 -> test
# Skin_108 -> test
# VOC2010_159 -> test
# 35043 -> test
# VOC2007_655 -> test
# Movie_4weds_225 -> test
# Buffy_364 -> test
# 36013 -> test
# VOC2010_1430 -> test
# 37045 -> test
# 22091 -> test
# 6075 -> test
# Poselet_35 -> test
# 215 -> test
# VOC2010_148 -> test
# 36023 -> test
# Inria_156 -> test
# Movie_4weds_89 -> test
# Movie_forrest_3 -> test
# 19018 -> test
# 40743 -> test
# VOC2007_469 -> test
# Movie_4weds_258 -> test
# 14009 -> test
# 29008 -> test
# 2045 -> test
# 29048 -> test
# VOC2010_637 -> test
# 5022 -> test
# 36010 -> test
# 9083 -> test
# 26055 -> test
# 82 -> test
# 40111 -> test
# VOC2010_430 -> test
# 38033 -> test
# Poselet_118 -> test
# Poselet_67 -> test
# 6028 -> test
# 19049 -> test
# 37019 -> test
# Inria_428 -> test
# VOC2010_1151 -> test
# 22043 -> test
# 19033 -> test
# 40748 -> test
# Movie_apollo13_6 -> test
# VOC2010_883 -> test
# VOC2010_177 -> test
# Skin_103 -> test
# 11070 -> test
# 12039 -> test
# 13075 -> test
# 24082 -> test
# Movie_apollo13_142 -> test
# VOC2007_804 -> test
# VOC2010_1157 -> test
# 33095 -> test
# 15030 -> test
# 29003 -> test
# 23083 -> test
# 4085 -> test
# 16077 -> test
# Inria_27 -> test
# Inria_497 -> test
# VOC2010_339 -> test
# 4021 -> test
# 35069 -> test
# 3065 -> test
# 3057 -> test
# Movie_4weds_59 -> test
# Skin_36 -> test
# Movie_4weds_204 -> test
# Buffy_95 -> test
# 23011 -> test
# 7089 -> test
# VOC2010_495 -> test
# Poselet_203 -> test
# 30023 -> test
# VOC2010_432 -> test
# Poselet_171 -> test
# 40811 -> test
# 16088 -> test
# 3048 -> test
# 40229 -> test
# 193 -> test
# Skin_297 -> test
# VOC2007_291 -> test
# VOC2010_212 -> test
# Buffy_245 -> test
# 18060 -> test
# Inria_229 -> test
# 40585 -> test
# Inria_336 -> test
# VOC2007_390 -> test
# Buffy_225 -> test
# Buffy_182 -> test
# Poselet_31 -> test
# 36069 -> test
# Skin_220 -> test
# Inria_7 -> test
# 18011 -> test
# 40488 -> test
# 2006 -> test
# VOC2010_953 -> test
# Skin_181 -> test
# 40379 -> test
# 1077 -> test
# 15063 -> test
# Buffy_371 -> test
# VOC2010_542 -> test
# VOC2010_995 -> test
# 25029 -> test
# 1000
# 1000
# 0
# 0

# %%
# extract only useful data(if not already present)
datasets_extr = ["hand_dataset/training_dataset/training_data/",
                 "hand_dataset/validation_dataset/validation_data/",
                 "hand_dataset/test_dataset/test_data/"]



with tarfile.open('hand_dataset.tar.gz') as archive:
    for file_name in archive.getnames():
        if any(s in file_name for s in datasets_extr) and not ("._.DS_Store" in file_name or ".DS_Store" in file_name):
            if not os.path.exists(os.path.join(".", file_name)):
                archive.extract(file_name, path=".")

# %% [markdown]
# ### 4) Check conversions
# Now to check if the conversion result is correct by visualizing random samples for each subset of the dataset and drawing the converted bounding box(es) onto it.<br>
# We also have shown original bounding boxes to see the difference between those and the converted ones

# %%
for dir_path in datasets_extr:
    # randomly select an image
    rnd_img = random.choice(os.listdir(dir_path + "images/"))

    # open the image
    img = Image.open(dir_path + "images/" + rnd_img)

    # create figure and axes
    fig, ax = plt.subplots(dpi=163)

    # display the image
    ax.imshow(img)

    #covert line string into ndarray
    bbox_yolo_coords = []
    with open(dir_path + "labels/" + rnd_img[:len(rnd_img)-4] + ".txt") as txt:

        lines = txt.read().splitlines()
        for line in lines:
            bbox_yolo_coords.append(np.fromstring(line[1:], dtype=float, sep=' ', count=4))
    
    # de-normalize coordinates and draw bbox onto img
    for box in bbox_yolo_coords:
        box[0] *= float(img.width)
        box[2] *= float(img.width)
        box[1] *= float(img.height)
        box[3] *= float(img.height)
        ax.add_patch(patches.Rectangle((box[0]-box[2]/2., box[1]-box[3]/2.), width=box[2], height=box[3], linewidth=1, edgecolor='r', facecolor='none'))
    
    # now draw original bbox in green
    mat_coords = extract_annotation(annotations_full_path=dir_path + "annotations/" + rnd_img[:len(rnd_img)-4] + ".mat")
    for mat_bbox in mat_coords:
        ax.add_patch(patches.Polygon(mat_bbox, linewidth=0.7, edgecolor='g', facecolor='none'))

    plt.show()

# %% [markdown]
# ### 5) Last steps before training
# Now we need to setup last things to train the yolo model. We will follow the following steps:
# - Copy images and labels into a directory system suitable to yolov5

# %%
dirs = ["./images/", "./labels/", "./images/train/", "./labels/train/", "./images/val/", "./labels/val/", "./images/test/", "./labels/test/"]
for dir_ in dirs:
    if not os.path.exists(dir_):
        os.mkdir(dir_)

# move dataset into directories "images" and "labels" which are located in same position as the notebook
subsets = ["train/", "val/", "test/"]
for i in range(3):
    for img_name in os.listdir(datasets_extr[i] + "images/"):
        old_img_path = datasets_extr[i] + "images/" + img_name
        old_lbl_path = datasets_extr[i] + "labels/" + img_name[:len(img_name)-3] + "txt"
        new_img_path = dirs[0] + subsets[i] + img_name
        new_lbl_path = dirs[1] + subsets[i] + img_name[:len(img_name)-3] + "txt"

        # copy img if it's not already there
        if not os.path.exists(new_img_path):
            shutil.copyfile(old_img_path, new_img_path)
        if not os.path.exists(new_lbl_path):
            shutil.copyfile(old_lbl_path, new_lbl_path)

# %% [markdown]
# - Create dataset location _yaml_ file (In our case move the premade one into the right directory)

# %%
# move data.yaml
new_data_yaml = "./yolov5/data/hand_data.yaml"
if os.path.exists(new_data_yaml):
    os.remove(new_data_yaml)
shutil.copyfile("./hand_data.yaml", new_data_yaml)


print("------------------ hand_data.yaml ---------------------")
with open(new_data_yaml) as f:
    lines = f.read().splitlines()
    for line in lines:
        print("\t" + line)
print("-------------------------------------------------------")

# %% [markdown]
# - Setup hyperparameters file, which will contain all usual parameters used when training a neural network (Same as before, we will move the premade one into the right directory)<br>
#   We are just going to use the default one

# %%
hyperparams_yaml = "./yolov5/data/hyps/hyp.scratch-med.yaml"
print("-------------------------------------------------- hyp.scratch-med.yaml -----------------------------------------------------")
with open(hyperparams_yaml) as f:
    lines = f.read().splitlines()
    for line in lines:
        print("\t" + line)
print("-----------------------------------------------------------------------------------------------------------------------------")
# Out:
# -------------------------------------------------- hyp.scratch-med.yaml -----------------------------------------------------
# 	# YOLOv5 🚀 by Ultralytics, GPL-3.0 license
# 	# Hyperparameters for medium-augmentation COCO training from scratch
# 	# python train.py --batch 32 --cfg yolov5m6.yaml --weights '' --data coco.yaml --img 1280 --epochs 300
# 	# See tutorials for hyperparameter evolution https://github.com/ultralytics/yolov5#tutorials
#
# 	lr0: 0.01  # initial learning rate (SGD=1E-2, Adam=1E-3)
# 	lrf: 0.1  # final OneCycleLR learning rate (lr0 * lrf)
# 	momentum: 0.937  # SGD momentum/Adam beta1
# 	weight_decay: 0.0005  # optimizer weight decay 5e-4
# 	warmup_epochs: 3.0  # warmup epochs (fractions ok)
# 	warmup_momentum: 0.8  # warmup initial momentum
# 	warmup_bias_lr: 0.1  # warmup initial bias lr
# 	box: 0.05  # box loss gain
# 	cls: 0.3  # cls loss gain
# 	cls_pw: 1.0  # cls BCELoss positive_weight
# 	obj: 0.7  # obj loss gain (scale with pixels)
# 	obj_pw: 1.0  # obj BCELoss positive_weight
# 	iou_t: 0.20  # IoU training threshold
# 	anchor_t: 4.0  # anchor-multiple threshold
# 	# anchors: 3  # anchors per output layer (0 to ignore)
# 	fl_gamma: 0.0  # focal loss gamma (efficientDet default gamma=1.5)
# 	hsv_h: 0.015  # image HSV-Hue augmentation (fraction)
# 	hsv_s: 0.7  # image HSV-Saturation augmentation (fraction)
# 	hsv_v: 0.4  # image HSV-Value augmentation (fraction)
# 	degrees: 0.0  # image rotation (+/- deg)
# 	translate: 0.1  # image translation (+/- fraction)
# 	scale: 0.9  # image scale (+/- gain)
# 	shear: 0.0  # image shear (+/- deg)
# 	perspective: 0.0  # image perspective (+/- fraction), range 0-0.001
# 	flipud: 0.0  # image flip up-down (probability)
# 	fliplr: 0.5  # image flip left-right (probability)
# 	mosaic: 1.0  # image mosaic (probability)
# 	mixup: 0.1  # image mixup (probability)
# 	copy_paste: 0.0  # segment copy-paste (probability)
# -----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - A custom network architecture can also be specified by specifing with _-cfg_ argument the custom network architecture file.<br>
#   Below there is and example taken from a default yolo network architecture

# %%
net_architecture_yaml = "./yolov5/models/yolov5l.yaml"
print("------------------------------------------------------ yolov5m.yaml --------------------------------------------------------")
with open(net_architecture_yaml) as f:
    lines = f.read().splitlines()
    for line in lines:
        print("\t" + line)
print("-----------------------------------------------------------------------------------------------------------------------------")
# Out:
# ------------------------------------------------------ yolov5m.yaml --------------------------------------------------------
# 	# YOLOv5 🚀 by Ultralytics, GPL-3.0 license
#
# 	# Parameters
# 	nc: 80  # number of classes
# 	depth_multiple: 1.0  # model depth multiple
# 	width_multiple: 1.0  # layer channel multiple
# 	anchors:
# 	  - [10,13, 16,30, 33,23]  # P3/8
# 	  - [30,61, 62,45, 59,119]  # P4/16
# 	  - [116,90, 156,198, 373,326]  # P5/32
#
# 	# YOLOv5 v6.0 backbone
# 	backbone:
# 	  # [from, number, module, args]
# 	  [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
# 	   [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
# 	   [-1, 3, C3, [128]],
# 	   [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
# 	   [-1, 6, C3, [256]],
# 	   [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
# 	   [-1, 9, C3, [512]],
# 	   [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
# 	   [-1, 3, C3, [1024]],
# 	   [-1, 1, SPPF, [1024, 5]],  # 9
# 	  ]
#
# 	# YOLOv5 v6.0 head
# 	head:
# 	  [[-1, 1, Conv, [512, 1, 1]],
# 	   [-1, 1, nn.Upsample, [None, 2, 'nearest']],
# 	   [[-1, 6], 1, Concat, [1]],  # cat backbone P4
# 	   [-1, 3, C3, [512, False]],  # 13
#
# 	   [-1, 1, Conv, [256, 1, 1]],
# 	   [-1, 1, nn.Upsample, [None, 2, 'nearest']],
# 	   [[-1, 4], 1, Concat, [1]],  # cat backbone P3
# 	   [-1, 3, C3, [256, False]],  # 17 (P3/8-small)
#
# 	   [-1, 1, Conv, [256, 3, 2]],
# 	   [[-1, 14], 1, Concat, [1]],  # cat head P4
# 	   [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)
#
# 	   [-1, 1, Conv, [512, 3, 2]],
# 	   [[-1, 10], 1, Concat, [1]],  # cat head P5
# 	   [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)
#
# 	   [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
# 	  ]
# -----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 6) Training the yolo model

# %%
# 313 could be a good batch size (1,13,313,4069)
#!cd yolov5
# !python yolov5/train.py --img 1280 --cfg yolov5l.yaml --hyp hyp.scratch-med.yaml --batch 50 --epochs 50 --data hand_data.yaml --weights ' ' --workers 2 --name yolo_hand_localization

# %% [markdown]
# Now to download the results: first create a zip file, then download it

# %%
# !zip -r ./training_result_runs.zip ./yolov5/runs
